# %%
from ovito.io import *
from ovito.modifiers import CoordinationAnalysisModifier
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # ◆ Pure Systems

# %% [markdown]
# ## ▻ Radial Distribution Function

# %%
rdfl= pd.read_csv('density-1175-20x20/pure_liquid/rdf-pure_liquid.txt', sep=" ", skiprows=2, header=None) 
rdfc= pd.read_csv('pure_crystal/rdf-pure_crystal.txt', sep=" ", skiprows=2, header=None)

xl=rdfl[0]
yl=rdfl[1]

xc=rdfc[0]
yc=rdfc[1]

fig, ax = plt.subplots(1,2, figsize=(20,4), dpi=100, sharex=True, sharey=False)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

ax[0].plot(xl,yl, color='tab:blue')
ax[0].set_title('Pure Liquid')
ax[1].plot(xc,yc, color='tab:red')
ax[1].set_title('Pure Solid')
ax[0].set_ylabel('g(r)')
ax[0].set_xlabel('Pair separation distance')
ax[1].set_xlabel('Pair separation distance')

# plt.suptitle('RDF of pure systems', y=0.98, size=16)

## plt.savefig('results/rdf-analysis/rdf_pure_systems.png')
# Out:
# Text(0.5, 0, 'Pair separation distance')

# %% [markdown]
# ## ▻ Bond Orientational Order

# %%
q6r_l, lq6i_l = np.genfromtxt('density-1175-20x20/pure_liquid/dump-q.lammpstrj',skip_header=9, unpack=True, usecols=(5,6))
q6r_c, q6i_c = np.genfromtxt('pure_crystal/dump-q.lammpstrj',skip_header=9, unpack=True, usecols=(5,6))

fig, ax = plt.subplots(1,2, figsize=(12,4), dpi=100, sharex=True, sharey=False)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

ax[0].plot(q6r_l,'o', color='tab:blue')
ax[0].set_title('Pure Liquid')
ax[1].plot(q6r_c, 'o', color='tab:red')
ax[1].set_title('Pure Solid')

# plt.suptitle('Hexatic order parameter of of pure systems', y=0.98, size=16)


## plt.savefig('plot-results/bo-analysis/1175_bo_pure_systems.png')
# Out:
# Text(0.5, 1.0, 'Pure Solid')

# %% [markdown]
# # ◆ Seed of 55 atoms (different lattice spacings)

# %% [markdown]
# ## ▻ Radial Distribution Function

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydata55 = []

for i in scales:
    myfile55= pd.read_csv(f'density-1175-20x20/hex-{i}/55-atoms/rdf-55-atoms.txt', sep=" ", skiprows=2, header=None)
    mydata55.append(myfile55)
    
x55=[]
y55=[]

for i in range(6):
    xx55=mydata55[i][0]
    yy55=mydata55[i][1]
    x55.append(xx55)
    y55.append(yy55)
    
## ------------------- plot all together ----------------------
    
## for i in range(6):
    ## plt.plot(x55[i], y55[i], label=f'hex-{scales[i]}')
    
## plt.title('RDF of crystal seed of 55 atoms')
## plt.legend()    

## plt.savefig('plot-results/rdf-analysis/1175_joined_rdf_55atoms.png')


## ------------------- plot separately ----------------------


# lats=['1.70','1.52','1.38','1.29','1.20','1.13']

# fig, ax = plt.subplots(2, 3, figsize=(20,8), dpi=100, sharex=True, sharey=False)
# colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

# v=3
# for i in range(6):
#     if i<=2:
#         ax[0,i].plot(x55[i], y55[i], color=colors[i],label=f'a={lats[i]}')
#         ax[0,i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[0,i].legend(loc='upper right')
#     else:
#         ii=i-v
#         ax[1,ii].plot(x55[i], y55[i], color=colors[i],label=f'a={lats[i]}')
#         ax[1,ii].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[1,ii].legend(loc='upper right')
        

# plt.suptitle('ρ=1175/400 \n RDF of crystal seed of 55 atoms', y=0.95, size=16)

## plt.savefig('plot-results/rdf-analysis/1175_rdf_55atoms.png')

# %%
lats=['1.70','1.52','1.38','1.29','1.20','1.13']

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
        ax[i].plot(x55[i], y55[i], color=colors[i],label=f'a={lats[i]}')
        ax[i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
        ax[i].legend(loc='upper right')
        ax[0].set_ylabel('g(r)')
        ax[i].set_xlabel('Distance (r)')
        
# plt.suptitle('ρ=1175/400: RDF of 55 atoms crystal seed', y=0.95, size=10)

plt.savefig('plot-results/rdf-analysis/1175_rdf_55atoms_one_row.png', dpi=100,bbox_inches='tight')

# %% [markdown]
# ##  ▻ Bond Orientational Order

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydataq55 = []

for i in scales:
    myfileq55= np.genfromtxt(f'density-1175-20x20/hex-{i}/55-atoms/dump-q.lammpstrj',skip_header=9, unpack=True, usecols=(5,6))
    mydataq55.append(myfileq55)
    
xq55=[]
yq55=[]

for i in range(6):
    xxq55=mydataq55[i][0]
    yyq55=mydataq55[i][1]
    xq55.append(xxq55)
    yq55.append(yyq55)
    
## ------------------- plot all together ----------------------
    
## for i in range(6):
##     plt.plot(xq55[i], 'o', label=f'hex-{scales[i]}')
    
## plt.title('Crystal seed of 55 atoms')
## plt.legend()  

## ------------------- plot separately ----------------------

fig, ax = plt.subplots(2, 3, figsize=(15,6), dpi=100, sharex=True, sharey=False)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
    if i<=2:
        ax[0,i].plot(xq55[i],'o', color=colors[i])
        ax[0,i].set_title(f'hex-{scales[i]}')
    else:
        ii=i-v
        ax[1,ii].plot(xq55[i],'o', color=colors[i])
        ax[1,ii].set_title(f'hex-{scales[i]}')
        
plt.suptitle('ρ=1175/400: Hexatic order parameter of crystal seed of 55 atoms', y=0.98, size=12)

## plt.savefig('plot-results/bo-analysis/1175_bo_55atoms.png')
# Out:
# Text(0.5, 0.98, 'ρ=1175/400: Hexatic order parameter of crystal seed of 55 atoms')

# %% [markdown]
# # ◆ Seed of 109 atoms (different lattice spacings)

# %% [markdown]
# ## ▻ Radial Distribution Function

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydata109 = []

for i in scales:
    myfile109= pd.read_csv(f'density-1175-20x20/hex-{i}/109-atoms/rdf-109-atoms.txt', sep=" ", skiprows=2, header=None)
    mydata109.append(myfile109)
    
x109=[]
y109=[]

for i in range(6):
    xx109=mydata109[i][0]
    yy109=mydata109[i][1]
    x109.append(xx109)
    y109.append(yy109)
    
#------------------------- plot all together --------------------------
    
# for i in range(6):
#     plt.plot(x109[i], y109[i], label=f'hex-{scales[i]}')
    
# plt.title('RDF of crystal seed of 109 atoms')
# plt.legend()   

# plt.savefig('plot-results/rdf-analysis/1175_joined_rdf_109atoms.png')

#------------------------- plot all separate --------------------------

# lats=['1.70','1.52','1.38','1.29','1.20','1.13']

# fig, ax = plt.subplots(2, 3, figsize=(20,8), dpi=100, sharex=True, sharey=False)
# colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

# v=3
# for i in range(6):
#     if i<=2:
#         ax[0,i].plot(x109[i], y109[i], color=colors[i],label=f'a={lats[i]}')
#         ax[0,i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[0,i].legend(loc='upper right')
#     else:
#         ii=i-v
#         ax[1,ii].plot(x109[i], y109[i], color=colors[i],label=f'a={lats[i]}')
#         ax[1,ii].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[1,ii].legend(loc='upper right')
        

# plt.suptitle('ρ=1175/400 \n RDF of crystal seed of 109 atoms', y=0.95, size=16)

# plt.savefig('plot-results/rdf-analysis/1175_rdf_109atoms.png')

# %%
lats=['1.70','1.52','1.38','1.29','1.20','1.13']

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
        ax[i].plot(x109[i], y109[i], color=colors[i],label=f'a={lats[i]}')
        ax[i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
        ax[i].legend(loc='upper right')
        ax[0].set_ylabel('g(r)')
        ax[i].set_xlabel('Distance (r)')
        
# plt.suptitle('ρ=1175/400: RDF of 109 atoms crystal seed', y=0.95, size=10)

plt.savefig('plot-results/rdf-analysis/1175_rdf_109atoms_one_row.png' ,bbox_inches='tight')

# %% [markdown]
# ## ▻ Bond orientational order

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydataq109 = []

for i in scales:
    myfileq109= np.genfromtxt(f'density-1175-20x20/hex-{i}/109-atoms/dump-q.lammpstrj',skip_header=9, unpack=True, usecols=(5,6))
    mydataq109.append(myfileq109)
    
xq109=[]
yq109=[]

for i in range(6):
    xxq109=mydataq109[i][0]
    yyq109=mydataq109[i][1]
    xq109.append(xxq109)
    yq109.append(yyq109)
  
# ---------------------- plot all together ---------------------

# for i in range(6):
#     plt.plot(xq109[i], 'o', label=f'hex-{scales[i]}')
    
# plt.title('Crystal seed of 109 atoms')
# plt.legend()   


# ------------------------ plot all separate -----------------------------------

fig, ax = plt.subplots(2, 3, figsize=(15,6), dpi=100, sharex=True, sharey=False)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
    if i<=2:
        ax[0,i].plot(xq109[i],'o', color=colors[i])
        ax[0,i].set_title(f'hex-{scales[i]}')
    else:
        ii=i-v
        ax[1,ii].plot(xq109[i],'o', color=colors[i])
        ax[1,ii].set_title(f'hex-{scales[i]}')
plt.suptitle('Hexatic order parameter of crystal seed of 109 atoms', y=0.98, size=16)

## plt.savefig('plot-results/bo-analysis/1175_bo_109atoms.png')
# Out:
# Text(0.5, 0.98, 'Hexatic order parameter of crystal seed of 109 atoms')

# %% [markdown]
# # ◆ Seed of 163 atoms (different lattice spacings)

# %% [markdown]
# ## ▻ Radial Distribution Function

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydata163 = []

for i in scales:
    myfile163= pd.read_csv(f'density-1175-20x20/hex-{i}/163-atoms/rdf-163-atoms.txt', sep=" ", skiprows=2, header=None)
    mydata163.append(myfile163)
    
x163=[]
y163=[]

for i in range(6):
    xx163=mydata163[i][0]
    yy163=mydata163[i][1]
    x163.append(xx163)
    y163.append(yy163)

# ----------------------------- plot all together -----------------------
    
# for i in range(6):
#     plt.plot(x163[i], y163[i], label=f'hex-{scales[i]}')
    
# plt.title('RDF of crystal seed of 163 atoms')
# plt.legend()  

# plt.savefig('plot-results/rdf-analysis/1175_joined_rdf_163atoms.png')

# ----------------------------- plot all separate -----------------------

# lats=['1.70','1.52','1.38','1.29','1.20','1.13']

# fig, ax = plt.subplots(2, 3, figsize=(20,8), dpi=100, sharex=True, sharey=False)
# colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

# v=3
# for i in range(6):
#     if i<=2:
#         ax[0,i].plot(x163[i], y163[i], color=colors[i],label=f'a={lats[i]}')
#         ax[0,i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[0,i].legend(loc='upper right')
#     else:
#         ii=i-v
#         ax[1,ii].plot(x163[i], y163[i], color=colors[i],label=f'a={lats[i]}')
#         ax[1,ii].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
#         ax[1,ii].legend(loc='upper right')
        

# plt.suptitle('ρ=1175/400 \n RDF of crystal seed of 163 atoms', y=0.95, size=16)

## plt.savefig('plot-results/rdf-analysis/1175_rdf_163atoms.png')

# %%
lats=['1.70','1.52','1.38','1.29','1.20','1.13']

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
        ax[i].plot(x163[i], y163[i], color=colors[i],label=f'a={lats[i]}')
        ax[i].plot(xl,yl, alpha=0.6, color='tab:blue', label='Liquid')
        ax[i].legend(loc='upper right')
        ax[0].set_ylabel('g(r)')
        ax[i].set_xlabel('Distance (r)')
        
# plt.suptitle('ρ=1175/400: RDF of 163 atoms crystal seed', y=0.95, size=10)

plt.savefig('plot-results/rdf-analysis/1175_rdf_163atoms_one_row.png', bbox_inches='tight')

# %% [markdown]
# ## ▻ Bond orientational order

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
mydataq163 = []

for i in scales:
    myfileq163= np.genfromtxt(f'density-1175-20x20/hex-{i}/163-atoms/dump-q.lammpstrj',skip_header=9, unpack=True, usecols=(5,6))
    mydataq163.append(myfileq163)
    
xq163=[]
yq163=[]

for i in range(6):
    xxq163=mydataq163[i][0]
    yyq163=mydataq163[i][1]
    xq163.append(xxq163)
    yq163.append(yyq163)
  
# ---------------------------- plot all together -------------------------

# for i in range(6):
#     plt.plot(xq163[i], 'o', label=f'hex-{scales[i]}')
    
# plt.title('Crystal seed of 163 atoms')
# plt.legend()   

# ---------------------------- plot all separate ----------------------------------

fig, ax = plt.subplots(2, 3, figsize=(15,6), dpi=100, sharex=True, sharey=False)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

v=3
for i in range(6):
    if i<=2:
        ax[0,i].plot(xq163[i],'o', color=colors[i])
        ax[0,i].set_title(f'hex-{scales[i]}')
    else:
        ii=i-v
        ax[1,ii].plot(xq163[i],'o', color=colors[i])
        ax[1,ii].set_title(f'hex-{scales[i]}')
plt.suptitle('Hexatic order parameter of crystal seed of 163 atoms', y=0.98, size=16)

## plt.savefig('plot-results/bo-analysis/1175_bo_163atoms.png')
# Out:
# Text(0.5, 0.98, 'Hexatic order parameter of crystal seed of 163 atoms')

# %% [markdown]
# # ◆ RDF Analysis

# %% [markdown]
# ## ▻ RDF vs Lattice Spacing

# %%
xlat=[1.70,1.52,1.38,1.29,1.20,1.13]
# -------------------------------------- 55 atoms --------------------------------------
mylist55 = []
for i in range(6):
    maxvalues55=max(y55[i][120:140])
    mylist55.append(maxvalues55)

# -------------------------------------- 109 atoms --------------------------------------
mylist109 = []
for i in range(6):
    maxvalues109=max(y109[i][120:140])
    mylist109.append(maxvalues109)
    
# -------------------------------------- 163 atoms --------------------------------------
mylist163= []
for i in range(6):
    maxvalues163=max(y163[i][120:140])
    mylist163.append(maxvalues163)

# %%
mylist_rdfatoms=[mylist55, mylist109, mylist163]
atoms=['55','109','163'] # for the names

fig, ax = plt.subplots(1, 3, figsize=(20,4), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

for i in range(3):
    ax[i].plot(xlat,mylist_rdfatoms[i],'o', color=colors[i])
    ax[i].set_title(f'{atoms[i]} atoms', size=10)
    ax[0].set_ylabel('g(r)')
    ax[i].set_xlabel('Lattice Spacing')
        
## plt.suptitle('ρ=1175/400: RDF vs Lattice Spacing', y=1.05, size=16)

plt.savefig('plot-results/rdf-analysis/1175_rdf-vs-lattice.png', bbox_inches='tight')

# %% [markdown]
# ## ▻ RDF vs number of atoms

# %%
mylist_rdflatt=[]
for i in range(6):
    latts=[mylist55[i],mylist109[i],mylist163[i]]
    mylist_rdflatt.append(latts)
    
# ---------------------------- plot all separate ------------------------------    
    
# scales=['0.4','0.5','0.6','0.7','0.8','0.9']
# xn=[55,109,163] #number of atoms of seeds

# fig, ax = plt.subplots(2, 3, figsize=(20,8), dpi=100, sharex=True, sharey=False)
# colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

# v=3

# for i in range(6):
#     if i<=2:
#         ax[0,i].plot(xn,mylist_rdflatt[i],'o', color=colors[i])
#         ax[0,i].set_title(f'hex-{scales[i]}')
#     else:
#         ii=i-v
#         ax[1,ii].plot(xn,mylist_rdflatt[i],'o', color=colors[i])
#         ax[1,ii].set_title(f'hex-{scales[i]}')

# plt.suptitle('ρ=1175/400: RDF vs number of atoms', y=0.98, size=16)


# plt.savefig('plot-results/rdf-analysis/1175_rdf-vs-atoms.png')

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
lats=['1.70','1.52','1.38','1.29','1.20','1.13']
xn=[55,109,163] #number of atoms of seeds

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:pink', 'tab:olive', 'tab:brown' ]

v=3

for i in range(6):
        ax[i].plot(xn,mylist_rdflatt[i],'o', color=colors[i])
        ax[i].set_title(f'a={lats[i]}', size=10)
        # ax[i].legend(loc='upper left')
        ax[0].set_ylabel('g(r)')
        ax[i].set_xlabel('Seed size')

##plt.suptitle('ρ=1175/400: RDF vs number of atoms', y=0.98, size=10)


plt.savefig('plot-results/rdf-analysis/1175_rdf-vs-atoms_one_row.png', bbox_inches='tight')

# %% [markdown]
# # ◆ Bond Order Analysis

# %% [markdown]
# ## ▻  Histograms pure systems

# %%
fig, ax = plt.subplots(1, 2, figsize=(15,4), dpi=100, sharex=True, sharey=False)

ax[0].hist(q6r_l, alpha=0.5, bins=50, density=False, stacked=True, color='tab:blue')
ax[0].set_title('q6 histogram of pure liquid system')
ax[1].hist(q6r_c, alpha=0.5, bins=50, density=False, stacked=True, color='tab:red')
ax[1].set_title('q6 histogram of pure crystal system')

plt.suptitle('ρ=1175/400 \n Hexatic order parameter of pure systems', y=1.05, size=16)

## plt.savefig('plot-results/bo-analysis/histogram-pure_systems.png')
# Out:
# Text(0.5, 1.05, 'ρ=1175/400 \n Hexatic order parameter of pure systems')

# %% [markdown]
# ## ▻ Histograms 55 atoms

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
lats=['1.70','1.52','1.38','1.29','1.20','1.13'] 


fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

for i in range(6):
    x = xq55[i] #55 atoms q data
    ax[i].hist(x, alpha=0.5, bins=50, density=False, stacked=True, color=colors[i],label=f'a={lats[i]}')
    ax[i].hist(q6r_l, alpha=0.5, bins=50,stacked='True', label='liquid',color='tab:blue')
    ax[i].legend(loc='upper left')
    ax[0].set_ylabel('Frequency')
    ax[i].set_xlabel('q6')

# plt.suptitle('ρ=1175/400: Hexatic order parameter of crystal seed of 55 atoms', y=0.98, size=10)

plt.savefig('plot-results/bo-analysis/histogram-1175_55atoms.png', bbox_inches='tight')

# %% [markdown]
# ## ▻ Histograms 109 atoms

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']
lats=['1.70','1.52','1.38','1.29','1.20','1.13'] 

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

for i in range(6):
    x = xq109[i] #109 atoms q data
    ax[i].hist(x, bins=50,alpha=0.5, density=False, stacked=True, color=colors[i], label=f'a={lats[i]}')
    ax[i].hist(q6r_l, bins=50, alpha=0.5, label='liquid',color='tab:blue')
    ax[i].legend(loc='upper left')
    ax[0].set_ylabel('Frequency')
    ax[i].set_xlabel('q6')

# plt.suptitle('ρ=1175/400: Hexatic order parameter of crystal seed of 109 atoms', y=0.98, size=10)

plt.savefig('plot-results/bo-analysis/histogram-1175_109atoms.png', bbox_inches='tight')

# %% [markdown]
# ## ▻ Histograms 163 atoms

# %%
scales=['0.4','0.5','0.6','0.7','0.8','0.9']

fig, ax = plt.subplots(1, 6, figsize=(25,3), dpi=100, sharex=True, sharey=True)
colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:olive', 'tab:brown' ]

for i in range(6):
    x = xq163[i] #109 atoms q data
    ax[i].hist(x, alpha=0.5, bins=50, density=False, stacked=True, color=colors[i], label=f'a={lats[i]}')
    ax[i].hist(q6r_l, bins=50,alpha=0.5, label='liquid',color='tab:blue')
    ax[i].legend(loc='upper left')
    ax[0].set_ylabel('Frequency')
    ax[i].set_xlabel('q6 parameter')

# plt.suptitle('ρ=1175/400: Hexatic order parameter of crystal seed of 163 atoms', y=0.98, size=10)

plt.savefig('plot-results/bo-analysis/histogram-1175_163atoms.png', bbox_inches='tight')
